# %% [markdown]
# # **Segundo avance PIA**
#
#
# ### Equipo: 2
# ### Grupo: 003
# ### Frecuencia: Lunes
# ### Integrantes:
# - 	1726724 Tolentino Vargas Areli Fernanda
# -	1816658 Martínez Martínez Arlette
# -	1728777 Navarro Sosa Leslie Paola
# -	1794335 Prado Porras Nadia Valeria
# -	1812288 Reyes Joaquín Dayana Guadalupe

# %% [markdown]
# # 1) Título de la base de datos:
# - [Life Expentancy (Who)](https://www.kaggle.com/kumarajarshi/life-expectancy-who)

# %% [markdown]
# # 2) Descripción de los datos

# %% [markdown]
# a) Tipo de datos.

# %% [markdown]
# La base de datos esta constituida por indicadores demográficos, las columnas estan conformadas por tipo de dato númerico excepto la columna de país y de estatus ya que son de tipo texto.

# %% [markdown]
# b) Descripción de las columnas
#
# **País:** Lugar del cual se tomaron los datos.
#
# **Anio:** Indica el año en que se recopilaron los datos, por país se tomaron en cuenta del año 2000 al 2015.
#
# **Estatus:** Indica si el país es desarrollado (tiene un alto nivel de vida) o está en desarrollo (economía en transición).
#
# **Esperanza_de_Vida:** Esperanza de vida promedio al nacer, en años.
#
# **Mortalidad de adultos:** Número de muertes de adultos de ambos sexos entre 15 y 60 años por cada 1000 habitantes.
#
# **Mortalidad_infantil:** Número de muertes de niños por cada 1000 nacimientos vivos registrados, durante el primer año de vida.
#
# **Alcohol:** Registro de consumo de alcohol medido en litros de alcohol puro per cápita por año.
#
# **Porcentaje_de_gastos:** Gasto en salud como porcentaje del Producto Interno Bruto per cápita.
#
# **Hepatitis_B:** Cobertura de inmunización por hepatitis B (HepB) en porcentaje de niños de 1 año.
#
# **Sarampion:** Número de casos de sarampión notificados por cada 1000 habitantes.
#
# **Indice_Masa_Corporal:** Índice promedio de masa corporal de toda la población.
#
# **Muertes_niños_menores_a_5anios:** Número de muertes de niños menores de cinco años por cada 1000 habitantes.
#
# **Poliomelitis:** Cobertura de inmunización contra la poliomielitis (Pol3) en porcentaje de niños de 1 año.
#
# **Gasto_total:** Gasto público general en salud como porcentaje del gasto público total.
#
# **Difteria:** Cobertura de inmunización por difteria tétanos y tos ferina (DTP3) en porcentaje de niños de 1 año.
#
# **VIH/SIDA:** Muertes por cada 1 000 nacidos vivos VIH/SIDA (0-4 años).
#
# **PIB:** Producto Interno Bruto per cápita (en USD).
#
# **Población:** Población total del país.
#
# **Delgadez_1a19_anios:** Prevalencia de delgadez entre niños y adolescentes de 10 a 19 años en porcentaje
#
# **Delgadez_5a9_anios:** Prevalencia de delgadez entre niños de 5 a 9 años en porcentaje.
#
# **Composicion_de_los_ingresos_de_los_recursos:** Índice de Desarrollo Humano en términos de composición de ingresos de los recursos (índice que va de 0 a 1).
#
# **Escolarización:** Número de años de escolarización.

# %% [markdown]
# # 3) Justificación del uso de datos

# %% [markdown]
# Las características que nos llamaron la atención al elegir la base de datos Life Expectancy Data es que la mayor parte de los valores son numéricos, por lo que podemos aplicar diferentes métodos estadísticos y probabilísticos para poder clasificar e interpretar información que obtendremos a partir de observar los datos, realizar modelos, estimaciones, predicciones y conclusiones acerca de los mismos.
#
# El beneficio que nos aporta es practicar con una base de datos que es parecida a una utilizada en el ámbito laboral actuarial, lo que nos brinda una mejor noción de cómo trabajar con grandes cantidades de números, como extraer información importante de ellos y como utilizarla a nuestro favor para los propósitos específicos del área de interés profesional.

# %% [markdown]
# # 4) Objetivo final

# %% [markdown]
# La esperanza de vida es el número medio de años que se espera que siga viviendo una persona. Se puede calcular para diferentes edades y se realiza asumiendo que se mantienen las tasas de mortalidad por edad. Es una medida que resume la mortalidad de un país, permitiéndonos comparar por generaciones y analizar tendencias.
#
# Su interpretación y significado nos puede aportar información clave sobre el nivel de desarrollo del estado de bienestar de un país, ya que tener una vida larga y saludable es el mejor indicativo del desarrollo social.
#
# Su alargamiento es resultado, entre otras cuestiones, de las mejoras en alimentación, en sanidad, y sobre todo de una disminución de la mortalidad, pero también de otras cuestiones que conducen a las anteriores.
#
# Por lo tanto, nuestro objetivo es conocer y comparar la situación y las características de la condición de vida de diferentes países del mundo en distintos años, determinando que factores de los presentados influyen realmente en la esperanza de vida, en qué medida lo hacen y cómo es que se relacionan.

# %% [markdown]
# # 5) Preguntas de interés
# El conjunto de datos tiene como objetivo responder a las siguientes preguntas clave:
#
# - ¿Afectan realmente a la esperanza de vida varios factores de predicción que se han elegido inicialmente? ¿Cuáles son las variables predictoras que realmente afectan la esperanza de vida?
# - ¿La esperanza de vida tiene una correlación positiva o negativa con los hábitos alimenticios, el estilo de vida, el ejercicio, el tabaquismo, el consumo de alcohol, etc.

# %% [markdown]
# # Desarrollo de las herramientas.
# ## 1. Limpieza de datos

# %% [markdown]
# #### a) Mostrar lo datos sin manipulación:
# - Importar librerías y leer los datos.

# %%
import pandas as pd
import numpy as np
import json
import io
import csv
Datos= pd.read_csv('Life Expectancy Data.csv',na_values=[" "])
Datos
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %% [markdown]
# - Ver caraterísticas del archivo.

# %%
Datos = pd.read_csv('Life Expectancy Data.csv')
print("Numero de filas y columnas:",Datos.shape)
print("\nPrimeras 10 filas de datos:\n",Datos.head(10))
print("\nUltimas 10 filas de datos:\n",Datos.tail(10))
# Out:
# Numero de filas y columnas: (2938, 22)
#
# Primeras 10 filas de datos:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# ...

# %% [markdown]
# - Renombrando las columnas.

# %%
Datos.rename(columns = {'Country':'Pais','Year':'Anio','Status':'Estatus','Life expectancy ':'Esperanza_de_Vida','Adult Mortality':'Mortalidad_de_adultos','infant deaths':'Mortalidad_infantil','percentage expenditure':'Porcentaje_de_gastos','Hepatitis B':'Hepatitis_B' ,'Measles ':'Sarampion', ' BMI ': 'IMC','under-five deaths ': 'Muertes_menores_5anios' ,'Polio':'Poliomelitis', 'Total expenditure':'Gasto_total', 'Diphtheria ':'Difteria',' HIV/AIDS': 'VIH/SIDA', 'Population':'Poblacion', 'Income composition of resources':'Composicion_de_los_ingresos_de_los_recursos', 'Schooling':'Escolarizacion',' thinness  1-19 years':'Delgadez_1a19', ' thinness 5-9 years':'Delgadez_5a9','GDP':'PIB'},inplace=True)
print("\nNuevos nombres de las columnas",Datos.columns)
# Out:
# Nuevos nombres de las columnas Index(['Pais', 'Anio', 'Estatus', 'Esperanza_de_Vida', 'Mortalidad_de_adultos',
#        'Mortalidad_infantil', 'Alcohol', 'Porcentaje_de_gastos', 'Hepatitis_B',
#        'Sarampion', 'IMC', 'Muertes_menores_5anios', 'Poliomelitis',
#        'Gasto_total', 'Difteria', 'VIH/SIDA', 'PIB', 'Poblacion',
#        'Delgadez_1a19', 'Delgadez_5a9',
#        'Composicion_de_los_ingresos_de_los_recursos', 'Escolarizacion'],
#       dtype='object')

# %% [markdown]
# **Se realizó la nueva asignación de nombres a cada columna esto fue con la finalidad de llevar un orden y poder ubicar con facilidad nuestros datos.**

# %% [markdown]
# - Cambiar el tipo de dato de una columna

# %%
Datos['Anio']=Datos['Anio'].astype('float64')
print("\nEl nuevo tipo de dato de la columna Anio (año) es: ", Datos['Anio'].dtype)
# Out:
# El nuevo tipo de dato de la columna Anio (año) es:  float64

# %% [markdown]
# **Con la finalidad de que todos los valores sean del mismo tipo, teniendo en cuenta el no perder información.**

# %% [markdown]
# - Agrupación de datos por clases

# %%
print("\nClases de la columna Anio (año): ",Datos.Anio.unique())
año_2015=Datos[Datos['Anio']==2015.0]
# Out:
# Clases de la columna Anio (año):  [2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007. 2006. 2005. 2004.
#  2003. 2002. 2001. 2000.]

# %% [markdown]
# **Nuestro enfoque es en el año 2015, nuestra razón fue por que son los datos más actualizados hasta el momento, entonces esto nos permite poder ver el comportamiento que se ha llevado la esperanza de vida con cada una de estas enfermedades.**

# %% [markdown]
# #### b) Eliminar columnas no deseadas.

# %%
df=Datos.drop(['Delgadez_5a9','Delgadez_1a19','Porcentaje_de_gastos','Gasto_total','PIB','Composicion_de_los_ingresos_de_los_recursos','Escolarizacion'], axis = 1 )
df
# Out:
#              Pais    Anio     Estatus  Esperanza_de_Vida  \
# 0     Afghanistan  2015.0  Developing               65.0
# 1     Afghanistan  2014.0  Developing               59.9
# 2     Afghanistan  2013.0  Developing               59.9
# 3     Afghanistan  2012.0  Developing               59.5
# 4     Afghanistan  2011.0  Developing               59.2
# ...           ...     ...         ...                ...
# 2933     Zimbabwe  2004.0  Developing               44.3
# 2934     Zimbabwe  2003.0  Developing               44.5
# 2935     Zimbabwe  2002.0  Developing               44.8
# 2936     Zimbabwe  2001.0  Developing               45.3
# 2937     Zimbabwe  2000.0  Developing               46.0
#
#       Mortalidad_de_adultos  Mortalidad_infantil  Alcohol  Hepatitis_B  \
# 0                     263.0                   62     0.01         65.0
# 1                     271.0                   64     0.01         62.0
# ...

# %% [markdown]
# **Borraremos las columnas que no necesitamos para encontrar las respuestas a las preguntas de la sección 5. Ya que solo queremos basarnos en las enfermedades.**

# %% [markdown]
# #### c) Correcta manipulación de los datos nulos dentro de la base de datos.

# %%
print("\nExistencia de datos nulos por columna:\n",Datos.isnull().any())
print("\nCantidad de datos nulos por columna:\n",Datos.isnull().sum())
print("\nUltimas filas de datos:\n",Datos.tail(160))
# Out:
# Existencia de datos nulos por columna:
#  Pais                                           False
# Anio                                           False
# Estatus                                        False
# Esperanza_de_Vida                               True
# Mortalidad_de_adultos                           True
# Mortalidad_infantil                            False
# Alcohol                                         True
# Porcentaje_de_gastos                           False
# Hepatitis_B                                     True
# Sarampion                                      False
# IMC                                             True
# Muertes_menores_5anios                         False
# Poliomelitis                                    True
# Gasto_total                                     True
# Difteria                                        True
# VIH/SIDA                                       False
# PIB                                             True
# ...

# %% [markdown]
# **Decidimos no borrar los datos nulos, si no llenarlos con 'NaN' así de esta manera no perderemos la información, ya que sí los elimina.**

# %% [markdown]
# Como nuestro interés son los datos del 2015, considerarémos unicamente estos valores.

# %%
Data2015= df.loc[Datos.Anio==2015]
Data2015
# Out:
#                                     Pais    Anio     Estatus  \
# 0                            Afghanistan  2015.0  Developing
# 16                               Albania  2015.0  Developing
# 32                               Algeria  2015.0  Developing
# 48                                Angola  2015.0  Developing
# 64                   Antigua and Barbuda  2015.0  Developing
# ...                                  ...     ...         ...
# 2858  Venezuela (Bolivarian Republic of)  2015.0  Developing
# 2874                            Viet Nam  2015.0  Developing
# 2890                               Yemen  2015.0  Developing
# 2906                              Zambia  2015.0  Developing
# 2922                            Zimbabwe  2015.0  Developing
#
#       Esperanza_de_Vida  Mortalidad_de_adultos  Mortalidad_infantil  Alcohol  \
# 0                  65.0                  263.0                   62     0.01
# ...

# %% [markdown]
# #### e) Crear un nuevo archivo con la base de datos editada.

# %%
Data2015.to_csv('Esperanza_de_vidaLimpio.csv',index=False)

# %% [markdown]
# ## 2. Estadística básica de los datos.

# %% [markdown]
# Verificamos que no haya una cantidad muy grande datos nulos en las columnas.

# %%
print('\nCantidad de datos no nulos de la columnas:\n', Data2015.count())
# Out:
# Cantidad de datos no nulos de la columnas:
#  Pais                      183
# Anio                      183
# Estatus                   183
# Esperanza_de_Vida         183
# Mortalidad_de_adultos     183
# Mortalidad_infantil       183
# Alcohol                     6
# Hepatitis_B               174
# Sarampion                 183
# IMC                       181
# Muertes_menores_5anios    183
# Poliomelitis              183
# Difteria                  183
# VIH/SIDA                  183
# Poblacion                 142
# dtype: int64

# %% [markdown]
# Una vez que observamos que hay muchos datos faltantes de Alcohol la eliminamos.

# %%
Data2015= Data2015.drop(['Alcohol'], axis = 1 )

# %% [markdown]
# Revisamos la información estadística de cada variable que consideramos influye en la esperanza de vida. Dado que nuestro objetivo es comparar esta información y ver cómo influyen.

# %%
print('Resumen Estadístico de los datos en el 2015:\n',Data2015.drop(['Anio','Esperanza_de_Vida'], axis = 1 ).describe())
print('Desviación Estandar:\n', Data2015.std())
print('\nVarianza:\n', Data2015.var())
print('\nAsimetría:\n', Data2015.skew())
print('\nCurtosis:\n', Data2015.kurt())
# Out:
# Resumen Estadístico de los datos en el 2015:
#         Mortalidad_de_adultos  Mortalidad_infantil  Hepatitis_B     Sarampion  \
# count             183.000000           183.000000   174.000000    183.000000
# mean              152.863388            23.803279    82.425287   1502.901639
# std                97.561184            83.683762    24.008492   7842.394928
# min                 1.000000             0.000000     6.000000      0.000000
# 25%                74.000000             0.000000    78.750000      0.000000
# 50%               138.000000             2.000000    93.000000     17.000000
# 75%               213.000000            17.000000    97.000000    202.000000
# max               484.000000           910.000000    99.000000  90387.000000
#
#               IMC  Muertes_menores_5anios  Poliomelitis    Difteria  \
# count  181.000000              183.000000    183.000000  183.000000
# mean    42.754144               31.612022     83.207650   84.633880
# ...

# %% [markdown]
# Para contestar a la pregunta 2, de la sección 5) decidimos obtener la correlación de la esperanza de vida contra las enfermedades como lo son el sarampión, la hepatitis B, el VIH/SIDA, y cómo influye el IMC.

# %%
Data2015.corr()
# Out:
#                         Anio  Esperanza_de_Vida  Mortalidad_de_adultos  \
# Anio                     NaN                NaN                    NaN
# Esperanza_de_Vida        NaN           1.000000              -0.779119
# Mortalidad_de_adultos    NaN          -0.779119               1.000000
# Mortalidad_infantil      NaN          -0.241290               0.188205
# Hepatitis_B              NaN           0.420848              -0.231715
# Sarampion                NaN          -0.074617               0.051196
# IMC                      NaN           0.516663              -0.369920
# Muertes_menores_5anios   NaN          -0.271921               0.212004
# Poliomelitis             NaN           0.515602              -0.372392
# Difteria                 NaN           0.500300              -0.322688
# VIH/SIDA                 NaN          -0.608345               0.621012
# Poblacion                NaN          -0.048461               0.046170
#
# ...

# %% [markdown]
# **De la tabla de correlación anterior, podemos destacar que el IMC es el que tiene mayor correlación con respecto a la esperanza de vida que las otras enfermedades. Es decir, que sí influye el IMC.**
#
# **Sin embargo, tiene correlación negativa con el sarampión y el VIH.**

# %% [markdown]
# ## 3. Gráficas.

# %% [markdown]
# Graficamos mediante un histograma la Esperanza de Vida para tener una idea de los valores en los que ronda.

# %%
Data2015['Esperanza_de_Vida'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# **Del histograma anterior, podemos deducir que la frecuencia de la esperanza de vida a la edad de 75 años es la más alta comparada con la edad de 85 años que es la más baja.**

# %% [markdown]
# Específicamente y de manera gráfica, revisamos si existe una relación entre las variables de Esperanza de Vida y el IMC.

# %%
Data2015.plot.scatter(x='Esperanza_de_Vida', y='IMC')
# Out:
# <AxesSubplot:xlabel='Esperanza_de_Vida', ylabel='IMC'>

# %% [markdown]
# **Concluimos que sí hay relación entre las variables de Esperanza de Vida y el IMC, pero es baja.**

# %% [markdown]
# Comparación de cobertura de inmunización por enfermedades más comunes en el mundo ( hepatitis B, poliomelitis y difteria tétanos/tos ferina) en porcentaje de niños de 1 año.

# %%
DS= Data2015.drop(['Pais','Estatus','Anio','Estatus','Esperanza_de_Vida','Mortalidad_de_adultos','Mortalidad_infantil','IMC','VIH/SIDA','Poblacion','Muertes_menores_5anios'], axis = 1 ).head(10)
DS.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **De acuerdo a la gráfica, concluimos que la difteria tiene más cifras de inmunidad, dado a que tiene mayor frecuencia.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# El mapa de correlación lo hicimos para saber exactamete el nivel de correlación que existe entre cada una de las variables. Así podremos identificar fácilmente que variables son las que mas afectan a la esperanza de vida.

# %%
f,ax=plt.subplots(figsize=(13,13))
sns.heatmap(Data2015.corr(),annot=True,linewidths=0.5,fmt=".2f",ax=ax)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.title('Mapa de correlación')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# **Podemos ver que las variables que mas afectan a la esperanza de vida son: Hepatitis B, el IMC, Poliomelitis y Difteria.**

# %% [markdown]
# ## Conclusión global:
#
# Modificamos ligeramente uno de nuestros objetivos, ya que previamente habíamos redactado las preguntas de interés con un enfoque más general, ahora dirigimos nuestro objetivo hacia ciertas variables en específico puesto que a medida que avanzamos en el proceso de trabajar con los datos, observamos que muchos de ellos no son necesarios o no tienen gran relevancia en nuestros futuros resultados, esto conllevará a que la conclusión final vaya de la mano con las preguntas de interés.
